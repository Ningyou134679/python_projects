# %%
from pyspark.sql.types import *
from pyspark.sql import *
from pyspark.sql.functions import *

# %%
from pyspark.context import SparkContext
from pyspark.sql.session import SparkSession
sc = SparkContext('local')
spark = SparkSession(sc)

# %%
data = [
    {
     'title': 'indeed',
     'user': '影1346xx@gめーる',
     'pass': 'ランダム033',
     'labels': ['website', 'work', 'career', 'recruitment']
     },
    {
     'title': 'マギレコ',
     'user': 'BuRzYDhb',
     'pass': '(N)ななし427',
     'msg': 'us acc',
     'labels': ['game', 'ios', 'マギレコ']
     },
    {
     'title': 'マギレコ',
     'user': 'hHwSyzmT',
     'pass': '(R)ランダム96tanjobi',
     'msg': 'cn acc',
     'labels': ['game', 'ios', 'マギレコ']
     },
    {
     'title': 'asobimo',
     'user': 'ダンテ1346xx@gめーる',
     'pass': '(R)ランダム96tanjobi',
     'labels': ['game', 'ios', 'asobimo']
     },
    {
     'title': 'ラグオリ',
     'user': 'ダンテ1346xx@gめーる',
     'msg': 'ggl login にんぎょう acc',
     'labels': ['game', 'ios', 'ラグオリ']
     },
    {
     'title': 'ラグオリ',
     'user': 'かげ1346xx@gめーる',
     'msg': 'ggl login ヤドカリ acc',
     'labels': ['game', 'ios', 'ラグオリ']
     },
    {
     'title': 'e克斯プレス',
     'user': 'しず112019@outlook',
     'pass': '@らんだむ033',
     'msg': 'EUF3RHKRATSWVFY58ATLFYB',
     'labels': ['vpn']
     },
    {
     'title': '12ビピン',
     'user': 'しず112019@outlook',
     'pass': '@らんだむ96tanjo',
     'msg': 'lamujewupu:tasuluwuge, blockthis.xyz, sk.blockthis.xyz',
     'labels': ['vpn']
     },
    {
     'title': 'ucss',
     'user': 'しず112020@outlook',
     'pass': '@らんだむ_96tanjo',
     'labels': ['vpn']
     },
    {
     'title': 'えっちえすぎんこう',
     'pass': '(96tan)MMddyyyy',
     'msg': 'はーど token',
     'labels': ['waku', 'career', 'えっちえすぎんこう']
     },
    {
     'title': 'えっちえすぎんこう',
     'pass': '(96tan)yyyyMM',
     'msg': 'そふと token',
     'labels': ['waku', 'career', 'えっちえすぎんこう']
     },
    {
     'title': 'えっちえすぎんこう',
     'user': '450なな7337',
     'pass': '@しごとMMyyyy',
     'msg': 'すたっふcred',
     'labels': ['waku', 'career', 'えっちえすぎんこう']
     },
    {
     'title': 'てくSystems',
     'user': 'しず2019@outlook',
     'pass': 'しごと082023',
     'msg': 'timesheet https://allegisgroup-apac1.force.com/community/s/',
     'labels': ['waku', 'career', 'あれぎす']
     },
    {
     'title': 'てくSystems-しゃんはい微服',
     'user': 'しし0103193285130181',
     'pass': 'しごと2020',
     'msg': 'mobile:いちさんきゅう2885756san;email:しず2019@o',
     'labels': ['waku', 'あれぎす']
     },
    {
     'title': 'ringo',
     'user': 'かげ134679@gめーる',
     'pass': '@(N)にんぎょう_96tan',
     'msg': '',
     'labels': ['ios', 'ringo']
     },
    {
     'title': 'ringo',
     'user': 'とり062019@outlook',
     'pass': '@ななし_stanley',
     'msg': '',
     'labels': ['ios', 'ringo']
     },
    {
     'title': 'guguru',
     'user': 'かげ134679@gmail',
     'pass': '@(N)にんぎょう_96tan',
     'msg': '',
     'labels': ['guguru']
     },
    {
     'title': 'guguru',
     'user': 'だんて@g',
     'pass': 'せいば9182',
     'msg': '',
     'labels': ['guguru']
     },
    {
     'title': 'guguru',
     'user': 'しず134679@g',
     'pass': 'せいば9182',
     'msg': '',
     'labels': ['guguru']
     },
    {
     'title': 'guguru',
     'user': 'にんぎょう0330@g',
     'pass': 'Olive918273xxx',
     'msg': '',
     'labels': ['guguru']
     },
    {
     'title': 'guguru',
     'user': 'ななしarchive01@g',
     'pass': 'ななし4xx',
     'msg': '',
     'labels': ['guguru']
     },
    {
     'title': 'outlook',
     'user': 'しず112019@outlook',
     'pass': '@ななしstanley',
     'msg': 'RHQSF-XSEE4-NMYNW-BQUAV-8XHR2',
     'labels': ['email', 'outlook']
     },
    {
     'title': 'outlook',
     'user': 'とり062019@outlook',
     'pass': '@ななしstanley',
     'msg': 'せきゅ アレックス カラフィナ 202011',
     'labels': ['email', 'outlook']
     },
    {
     'title': 'outlook',
     'user': 'しず112020@outlook',
     'pass': '@ななし_年',
     'labels': ['email', 'outlook']
     },
    {
     'title': 'ちゅうごく半苦',
     'user': 'roku217857000083921682',
     'msg': 'しはらい 96tanjo99, app 96(N)ねこ96tan',
     'labels': ['ばんく']
     },
    {
     'title': 'kensetsu半苦',
     'user': 'roku214673320014037898',
     'pass': 'marusannsann*2',
     'msg': '',
     'labels': ['ばんく']
     },
    {
     'title': 'ちぇーs',
     'user': 'みなづき1346',
     'pass': 'にんぎょう113',
     'msg': 'しはらい 96tanjo99, app 96(N)ねこ96tan',
     'labels': ['ばんく']
     },
    {
     'title': 'うぃチャット',
     'user': 'いちさんきゅう28857563,しず112020',
     'pass': '@しごと_2021',
     'msg': 'sizbk2020:らんだむ4になな',
     'labels': ['app','sns']
     },
    {
     'title': 'jingHigashi',
     'user': 'こたつ11',
     'pass': '@随机stanley',
     'labels': ['app','shopping']
     },
    {
     'title': 'tb',
     'user': 'tb793113637',
     'pass': '(R)らんだむ_96tan',
     'labels': ['app','shopping']
     },
    {
     'title': 'google',
     'user': 'しもんしず427@gmail',
     'pass': 'らんどむ427',
     'msg': '',
     'labels': ['google']
     },
    {
     'title': 'mega',
     'user': 'だんて1346xx@gmail',
     'pass': 'らんどむ427',
     'msg': '',
     'labels': ['mega','cloud']
     },
    {
     'title': 'mega',
     'user': 'しず112020@out',
     'pass': '@らんどむ96tan',
     'msg': '',
     'labels': ['mega','cloud']
     },
    {
     'title': 'linkedin',
     'user': 'しず112019@out',
     'pass': 'らんどむ96tan',
     'msg': '',
     'labels': ['website']
     },
    {
     'title': 'きゅうきゅう',
     'user': 'とり2020',
     'pass': 'なにか96tan',
     'msg': '',
     'labels': ['app','sns']
     },
    {
     'title': 'h1',
     'user': 'ichisankyu2885756san',
     'pass': '',
     'msg': 'addr:cliff,yuemingxuan,0506108;net:smch,びんふぇん2302;mokudoa:96698765;tetsudoa:MMddyyyy@96',
     'labels': ['ie']
     },
    {
     'title': 'keitai',
     'user': 'ichisankyu2885756san',
     'pass': 'MMdd(96)99',
     'msg': 'cn mobile',
     'labels': ['keitai']
     },
    {
     'title': 'git',
     'user': '人形1346xx',
     'pass': '@らんだむ_96tan',
     'msg': 'gえっちぴ_6t6QlgbCwDtfhzTQTbdjN79TRfulZi3H2ekD',
     'labels': ['git']
     },
    {
     'title': 'ファイアーフォックス',
     'user': 'しず2020@o',
     'pass': '@ななし_96tann',
     'msg': 'えいえむHE M2JK 6FS9 02VR 97PD M1GQ AE18 BCJ0',
     'labels': ['website']
     }
    ,
    {
     'title': 'いわら',
     'user': 'らんだむ_user2020',
     'pass': 'らんどむ_Password_2020',
     'msg': '',
     'labels': ['website']
     },
    {
     'title': 'maku',
     'user': 'ていsiming',
     'pass': 'Doll96tan',
     'msg': 'C02JL286F897',
     'labels': ['pasokon']
     }
]
schema = StructType([
    StructField('title', StringType()),
    StructField('user', StringType()),
    StructField('pass', StringType()),
    StructField('msg', StringType()),
    StructField('labels', ArrayType(StringType())),
])

# %%
df = spark.createDataFrame(data, schema=schema).withColumn(
    "index",
    row_number().over(Window.orderBy(monotonically_increasing_id()))
).select("index","title","user","pass","msg","labels")
df.printSchema()
# Out:
# root
#  |-- index: integer (nullable = false)
#  |-- title: string (nullable = true)
#  |-- user: string (nullable = true)
#  |-- pass: string (nullable = true)
#  |-- msg: string (nullable = true)
#  |-- labels: array (nullable = true)
#  |    |-- element: string (containsNull = true)

# %%
df.show(5,truncate=False)
# Out:
# +-----+--------+--------------------+--------------------+------------------------+------------------------------------+
# |index|title   |user                |pass                |msg                     |labels                              |
# +-----+--------+--------------------+--------------------+------------------------+------------------------------------+
# |1    |indeed  |影1346xx@gめーる    |ランダム033         |null                    |[website, work, career, recruitment]|
# |2    |マギレコ|BuRzYDhb            |(N)ななし427        |us acc                  |[game, ios, マギレコ]               |
# |3    |マギレコ|hHwSyzmT            |(R)ランダム96tanjobi|cn acc                  |[game, ios, マギレコ]               |
# |4    |asobimo |ダンテ1346xx@gめーる|(R)ランダム96tanjobi|null                    |[game, ios, asobimo]                |
# |5    |ラグオリ|ダンテ1346xx@gめーる|null                |ggl login にんぎょう acc|[game, ios, ラグオリ]               |
# +-----+--------+--------------------+--------------------+------------------------+------------------------------------+
# only showing top 5 rows

# %%
df.write.parquet(path='pyspark_test.parquet', mode="overwrite")
output = df.withColumn('labels', col('labels').cast('string'))
output.write.csv(path='pyspark_test.csv', header="true", mode="overwrite")
#output.toPandas().to_csv("test.csv")

# %%
output_df = spark.read.parquet('pyspark_test.parquet', header = True)
print(output_df.count())
output_df.printSchema()
output_df.show(5,False)
# Out:
# 40
# root
#  |-- index: integer (nullable = true)
#  |-- title: string (nullable = true)
#  |-- user: string (nullable = true)
#  |-- pass: string (nullable = true)
#  |-- msg: string (nullable = true)
#  |-- labels: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#
# +-----+--------+--------------------+--------------------+------------------------+------------------------------------+
# |index|title   |user                |pass                |msg                     |labels                              |
# +-----+--------+--------------------+--------------------+------------------------+------------------------------------+
# |1    |indeed  |影1346xx@gめーる    |ランダム033         |null                    |[website, work, career, recruitment]|
# |2    |マギレコ|BuRzYDhb            |(N)ななし427        |us acc                  |[game, ios, マギレコ]               |
# |3    |マギレコ|hHwSyzmT            |(R)ランダム96tanjobi|cn acc                  |[game, ios, マギレコ]               |
# |4    |asobimo |ダンテ1346xx@gめーる|(R)ランダム96tanjobi|null                    |[game, ios, asobimo]                |
# |5    |ラグオリ|ダンテ1346xx@gめーる|null                |ggl login にんぎょう acc|[game, ios, ラグオリ]               |
# +-----+--------+--------------------+--------------------+------------------------+------------------------------------+
# only showing top 5 rows
